# %% [markdown]
# <a href="https://colab.research.google.com/github/dskumar355/DAA/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Learning Objectives
#
# By the end of the lesson, students will:
#
#     Understand what an algorithm is.
#
#     Know why we need to think before we code.
#
#     Learn one simple greedy algorithm (choose the best option first).
#
#     Be able to write a basic Python function with your help.

# %% [markdown]
# 📚 Materials Needed
#
#     Your laptop with Python installed (Jupyter or any IDE)
#
#     Whiteboard or drawing tool (optional)
#
#     Coins (real or printed) for interactive demo

# %%
print("Hello! Let's count money.heheh")
# Out:
# Hello! Let's count money.

# %% [markdown]
# # 🪙 **Problem: Minimum Number of Coins**

# %% [markdown]
#     Suppose you have to pay ₹20, and you have coins of ₹10, ₹5, ₹2, and ₹1.
#     What’s the fewest coins you can use?

# %% [markdown]
# 💡 I**dea: Use the biggest coins first**
#
#    This is called a Greedy Algorithm — it grabs the best option (biggest coin) at each step.

# %%
def greedy_coins(value):
    coins = [500,10, 5, 2, 1]
    result = []
    for coin in coins:
        while value >= coin:
            value -= coin
            result.append(coin)
    return len(result)

print(greedy_coins(27890))  # Output: [10, 5, 2, 1]
# Out:
# 94

# %% [markdown]
# A greedy algorithm is like picking the best-looking option right now without worrying about whether it’s the best choice for the whole problem.
# In this algo there is no need of backtracking.

# %%
while True:
   x = int(input("no 1 ::"))
   y = int(input("no 2 ::"))
   c = input("hehehehe")
   if c == "+":
     print(x + y)
   elif c == "-":
     print(x - y)
   elif c == "*":
     print(x * y)
   elif c == "/":
     print(x / y)
   else:
      print("🤪🤪")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2854701666> in <cell line: 0>()
#       1 while True:
# ----> 2    x = int(input("no 1 ::"))
#       3    y = int(input("no 2 ::"))
#       4    c = input("hehehehe")
#       5    if c == "+":
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # 📘 **Example: Check if a Number is Prime**

# %% [markdown]
# ---

# %% [markdown]
# Syllabus Reference: <br> Lab #1 – "Write a program to determine whether the given number is Prime or not."
#
# 🎯 **Goal**:
#
# how to:
#
#     Use loops
#
#     Use conditionals (if)
#
#     Understand a simple brute-force algorithm
#
# 🧠 **Problem Explanation**
#
#     A prime number is a number that has only 2 friends – 1 and itself.
#
#     If a number has more friends (divisors), it's not prime.
#
#     Examples: 2, 3, 5, 7, 11, 13
#
#     Not prime: 4, 6, 8, 9, 10 (because they can be divided by other numbers too)

# %%
def is_prime(n):
    if n <= 1:
        return False  # 0 and 1 are not prime
    for i in range(2, int(n ** 0.5) + 1):  # Check from 2 to sqrt(n)
        if n % i == 0:
            return False  # If divisible, not prime
    return True  # Otherwise, it's prime!
# Test it
num = 1586797313
if is_prime(num):
    print(f"{num} is a Prime Number ✅")
else:
    print(f"{num} is Not a Prime Number ❌")
# Out:
# 1586797313 is Not a Prime Number ❌

# %% [markdown]
# this algorithm checks if a number is prime! It first rules out numbers less than or equal to 1, then checks if the number is divisible by anything from 2 up to its square root. If it finds no divisors, it declares the number prime

# %%
# Test it
num = 13
if is_prime(num):
    print(f"{num} is a Prime Number ✅")
else:
    print(f"{num} is Not a Prime Number ❌")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-178212778> in <cell line: 0>()
#       1 # Test it
#       2 num = 13
# ----> 3 if is_prime(num):
#       4     print(f"{num} is a Prime Number ✅")
#       5 else:
#
# NameError: name 'is_prime' is not defined

# %% [markdown]
# 🧮 Why only go up to √n (square root of n)?
#
# Let’s say you’re checking if 36 is a prime:
#
# Factors of 36	Pair Form
# ```
# 1 × 36	→ (1, 36)
# 2 × 18	→ (2, 18)
# 3 × 12	→ (3, 12)
# 4 × 9 	→ (4, 9)
# 6 × 6	 → (6, 6) ← this is where we hit square root (√36 = 6)
#
# ```
#
#
#
# After this point, the factor pairs just repeat in reverse!
#
# So if you didn’t find any divisor before √n, you won’t find one after it either. That’s why we stop at √n.

# %%
while True:
  x = int(input("enter x"))
  y = int(input("enter y"))
  c = input("enter op")
  if c == "+":
    print(x + y)
  elif c =="-":
    print(x -y)
  else:
    print("noob")
